# %%
import cv2
import numpy as np
import matplotlib.pyplot as pyplot
import imutils

import tensorflow as tf
import keras.layers as layers
import keras.models as models
import keras.optimizers as optimizers

import keras

from keras import backend as K
from keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, Dropout
from keras.models import Model
from keras.layers.merge import concatenate

# %%
def image_generator(image_numbers,batch_size=8):
    i = 0
    while True:
        batch_x = []
        
        batch_y = {'item': [],'item_name': [], 'item_price': [],'total': []}
        
        batch_numbers = np.random.choice(image_numbers, batch_size)
        
        for i in batch_numbers:
            img = cv2.cvtColor(cv2.imread('html-render/augmented/' + str(i) + '.jpg'), cv2.COLOR_BGR2RGB)
            m_item = cv2.cvtColor(cv2.imread('html-render/augmented/' + str(i) + '_item.png'), cv2.COLOR_BGRA2GRAY)
            m_item_name = cv2.cvtColor(cv2.imread('html-render/augmented/' + str(i) + '_item-name.png'), cv2.COLOR_BGRA2GRAY)
            m_item_price = cv2.cvtColor(cv2.imread('html-render/augmented/' + str(i) + '_item-price.png'), cv2.COLOR_BGRA2GRAY)
            m_total = cv2.cvtColor(cv2.imread('html-render/augmented/' + str(i) + '_total.png'), cv2.COLOR_BGRA2GRAY)
            batch_x.append(img / 255.0)
            batch_y['item'].append(m_item.reshape((img.shape[0], img.shape[1], 1))/255.0)
            batch_y['item_name'].append(m_item_name.reshape((img.shape[0], img.shape[1], 1))/255.0)
            batch_y['item_price'].append(m_item_price.reshape((img.shape[0], img.shape[1], 1))/255.0)
            batch_y['total'].append(m_total.reshape((img.shape[0], img.shape[1], 1))/255.0)
        
        batch_x = np.array(batch_x)
        batch_y['item'] = np.array(batch_y['item'])
        batch_y['item_name'] = np.array(batch_y['item_name'])
        batch_y['item_price'] = np.array(batch_y['item_price'])
        batch_y['total'] = np.array(batch_y['total'])
        
        
        yield (batch_x, batch_y)

# %%
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
inp = models.Input((None, None, 3))
activation = 'elu'
l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(inp)
l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(l)
c1 = l
l = layers.MaxPool2D()(l)

l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(l)
l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(l)
c2 = l
l = layers.MaxPool2D()(l)

l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(l)
c3 = l
l = layers.MaxPool2D()(l)

l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(l)
c4 = l
l = layers.MaxPool2D()(l)

l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(l)
l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(l)
c5 = l
l = layers.MaxPool2D()(l)

item_l = layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(l)
item_l = concatenate([item_l, c5])
item_l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(item_l)

item_l = layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(item_l)
item_l = concatenate([item_l, c4])
item_l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(item_l)

item_l = layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(item_l)
item_l = concatenate([item_l, c3])
item_l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(item_l)

item_l = layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(item_l)
item_l = concatenate([item_l, c2])
item_l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(item_l)

###

item_item_l = layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(item_l)
item_item_l = concatenate([item_item_l, c1])
item_item_l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(item_item_l)

###

item_name_l = layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(item_l)
item_name_l = concatenate([item_name_l, c1])
item_name_l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(item_name_l)

###

item_price_l = layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(item_l)
item_price_l = concatenate([item_price_l, c1])
item_price_l = layers.Conv2D(8, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(item_price_l)

###

total_l = layers.Conv2DTranspose(4, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(l)
total_l = concatenate([total_l, c5])
total_l = layers.Conv2D(4, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(total_l)

total_l = layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(total_l)
total_l = concatenate([total_l, c4])
total_l = layers.Conv2D(4, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(total_l)

total_l = layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(total_l)
total_l = concatenate([total_l, c3])
total_l = layers.Conv2D(4, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(total_l)

total_l = layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(total_l)
total_l = concatenate([total_l, c2])
total_l = layers.Conv2D(4, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(total_l)

total_l = layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), activation=activation, kernel_initializer='he_normal', padding='same')(total_l)
total_l = concatenate([total_l, c1])
total_l = layers.Conv2D(4, (3, 3), activation=activation, kernel_initializer='he_normal', padding='same')(total_l)


item = layers.Conv2D(1, (1, 1), name='item', activation='sigmoid', kernel_initializer='he_normal', padding='same')(item_item_l)
item_name = layers.Conv2D(1, (1, 1), name='item_name', activation='sigmoid', kernel_initializer='he_normal', padding='same')(item_name_l)
item_price = layers.Conv2D(1, (1, 1), name='item_price', activation='sigmoid', kernel_initializer='he_normal', padding='same')(item_price_l)
total = layers.Conv2D(1, (1, 1), name='total', activation='sigmoid', kernel_initializer='he_normal', padding='same')(total_l)

model = models.Model(inp, [item, item_name, item_price, total])

# %%
model.compile(optimizer=optimizers.Adam(0.001), 
              loss={
                'item': 'binary_crossentropy',
                'item_name': 'binary_crossentropy',
                'item_price': 'binary_crossentropy',
                'total': 'binary_crossentropy'
              }, 
              metrics=[
                    mean_iou
              ])

# %%
#model.summary()
model = keras.models.load_model('items-segmentation-model.h5', custom_objects={'mean_iou': mean_iou})

# %%
p = np.random.permutation(np.arange(1, 1000))

# %%
model.fit_generator(
          image_generator(p[:900]),
          validation_data=image_generator(p[900:]),
          validation_steps=5,
          steps_per_epoch=100,
          epochs=10000,
          callbacks=[
              #keras.callbacks.EarlyStopping(monitor='val_mean_iou', patience=30, verbose=False, mode='max', baseline=None, restore_best_weights=True)
          ])
# Out:
# Epoch 1/10000
# 100/100 [==============================] - 30s 298ms/step - loss: 0.0627 - item_loss: 0.0391 - item_name_loss: 1.1241e-07 - item_price_loss: 0.0123 - total_loss: 0.0113 - item_mean_iou: 0.7316 - item_name_mean_iou: 1.0000 - item_price_mean_iou: 0.4979 - total_mean_iou: 0.4984 - val_loss: 0.0702 - val_item_loss: 0.0452 - val_item_name_loss: 1.1331e-07 - val_item_price_loss: 0.0139 - val_total_loss: 0.0111 - val_item_mean_iou: 0.7321 - val_item_name_mean_iou: 1.0000 - val_item_price_mean_iou: 0.4979 - val_total_mean_iou: 0.4984
# Epoch 2/10000
# 100/100 [==============================] - 29s 292ms/step - loss: 0.0634 - item_loss: 0.0396 - item_name_loss: 1.1567e-07 - item_price_loss: 0.0122 - total_loss: 0.0115 - item_mean_iou: 0.7324 - item_name_mean_iou: 1.0000 - item_price_mean_iou: 0.4979 - total_mean_iou: 0.4984 - val_loss: 0.0751 - val_item_loss: 0.0504 - val_item_name_loss: 1.1099e-07 - val_item_price_loss: 0.0132 - val_total_loss: 0.0116 - val_item_mean_iou: 0.7327 - val_item_name_mean_iou: 1.0000 - val_item_price_mean_iou: 0.4979 - val_total_mean_iou: 0.4984
# Epoch 3/10000
# 100/100 [==============================] - 29s 289ms/step - loss: 0.0621 - item_loss: 0.0385 - item_name_loss: 1.1539e-07 - item_price_loss: 0.0121 - total_loss: 0.0115 - item_mean_iou: 0.7327 - item_name_mean_iou: 1.0000 - item_price_mean_iou: 0.4979 - total_mean_iou: 0.4984 - val_loss: 0.0738 - val_item_loss: 0.0497 - val_item_name_loss: 1.0645e-07 - val_item_price_loss: 0.0132 - val_total_loss: 0.0110 - val_item_mean_iou: 0.7330 - val_item_name_mean_iou: 1.0000 - val_item_price_mean_iou: 0.4979 - val_total_mean_iou: 0.4984
# Epoch 4/10000
# 100/100 [==============================] - 29s 288ms/step - loss: 0.0641 - item_loss: 0.0402 - item_name_loss: 1.1007e-07 - item_price_loss: 0.0123 - total_loss: 0.0117 - item_mean_iou: 0.7329 - item_name_mean_iou: 1.0000 - item_price_mean_iou: 0.4979 - total_mean_iou: 0.4984 - val_loss: 0.0728 - val_item_loss: 0.0464 - val_item_name_loss: 1.0854e-07 - val_item_price_loss: 0.0142 - val_total_loss: 0.0122 - val_item_mean_iou: 0.7329 - val_item_name_mean_iou: 1.0000 - val_item_price_mean_iou: 0.4979 - val_total_mean_iou: 0.4984
# Epoch 5/10000
# 100/100 [==============================] - 29s 286ms/step - loss: 0.0625 - item_loss: 0.0389 - item_name_loss: 1.0809e-07 - item_price_loss: 0.0124 - total_loss: 0.0111 - item_mean_iou: 0.7330 - item_name_mean_iou: 1.0000 - item_price_mean_iou: 0.4979 - total_mean_iou: 0.4984 - val_loss: 0.0713 - val_item_loss: 0.0463 - val_item_name_loss: 1.1469e-07 - val_item_price_loss: 0.0133 - val_total_loss: 0.0116 - val_item_mean_iou: 0.7334 - val_item_name_mean_iou: 1.0000 - val_item_price_mean_iou: 0.4979 - val_total_mean_iou: 0.4984
# Epoch 6/10000
# 100/100 [==============================] - 29s 291ms/step - loss: 0.0611 - item_loss: 0.0381 - item_name_loss: 1.0849e-07 - item_price_loss: 0.0119 - total_loss: 0.0111 - item_mean_iou: 0.7337 - item_name_mean_iou: 1.0000 - item_price_mean_iou: 0.4979 - total_mean_iou: 0.4984 - val_loss: 0.0760 - val_item_loss: 0.0505 - val_item_name_loss: 1.1300e-07 - val_item_price_loss: 0.0141 - val_total_loss: 0.0114 - val_item_mean_iou: 0.7338 - val_item_name_mean_iou: 1.0000 - val_item_price_mean_iou: 0.4979 - val_total_mean_iou: 0.4984
# Epoch 7/10000
# 100/100 [==============================] - 29s 290ms/step - loss: 0.0634 - item_loss: 0.0395 - item_name_loss: 1.1283e-07 - item_price_loss: 0.0125 - total_loss: 0.0113 - item_mean_iou: 0.7343 - item_name_mean_iou: 1.0000 - item_price_mean_iou: 0.4979 - total_mean_iou: 0.4984 - val_loss: 0.0841 - val_item_loss: 0.0604 - val_item_name_loss: 1.1180e-07 - val_item_price_loss: 0.0117 - val_total_loss: 0.0120 - val_item_mean_iou: 0.7345 - val_item_name_mean_iou: 1.0000 - val_item_price_mean_iou: 0.4979 - val_total_mean_iou: 0.4984
# Epoch 8/10000
#   4/100 [>.............................] - ETA: 25s - loss: 0.0606 - item_loss: 0.0389 - item_name_loss: 1.0928e-07 - item_price_loss: 0.0104 - total_loss: 0.0113 - item_mean_iou: 0.7343 - item_name_mean_iou: 1.0000 - item_price_mean_iou: 0.4979 - total_mean_iou: 0.4984

# %%
model.save('items-segmentation-model.h5')

# %%
X = np.array([np.array(cv2.resize(cv2.cvtColor(cv2.imread('html-render/generated/1_origin.png'), cv2.COLOR_BGR2RGB), (320, 864))) / 255.0])

# %%
preds = model.predict(X)

# %%
pred = np.where(preds[1][0] > 0.001, 1, 0)
pred = pred.reshape((pred.shape[0], pred.shape[1]))

pyplot.figure(figsize=(30,20))
pyplot.imshow(X[0])
pyplot.figure(figsize=(30,20))
pyplot.imshow(pred)

pyplot.figure(figsize=(30,20))
x = X[0].copy()
x[pred == 0] = (255, 0, 0)
pyplot.imshow(x)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
