# %%
from PIL import Image, ImageDraw, ImageFont

# %%
bill_img = Image.new('RGB', (350, 1000), color=(255, 255, 255))
bill_img_draw = ImageDraw.Draw(bill_img)
unicode_font = ImageFont.truetype("UbuntuMono-R.ttf", 12)



a = '''
  ПІІ "МакДональдз Укрейн Лтд"
  Закусочна "Смілянська"
м. Черкаси. Вулиця Смілянська, 31
  Телефон закладу: (050) 463-91-20
  (0472) 54-52-35
  Телефон гарячої лінії :
          0-800-50-15-79
          ПН 237444526652
    ЗН СП802400259   ФН 3000477964
        Керімова Н. Каса 25
 ----------------------------------------
      ---- НОМЕР ЗАМОВЛЕННЯ: ----
          #####    #####   #####
         ##   ##  ##   ## ##   ##
         ##   ##   #####      ##
         ##   ##  ##   ##  ###
         ##   ##  ##   ## ##
         ##   ##  ##   ## ##
          #####    #####  #######
 -------------------------------------
 ЧІКЕН МАКНАГЕТС9 МЕН             109.00 А    
 СОУС СИРНИЙ                        8.00 А  
  * 1 КАРТОПЛЯНІ ДІПИ МЕНЮ
  * 1 ЧАЙ З БЕРГАМОТОМ МЕН
 ----------------------------------------
 Сума...
                ПДВ_А А = 20.00%    19.50
 ----------------------------------------
 Картка                            117.00
 Транзакція №:
 912382880468
 ----------------------------------------
 АТ ОЩАДБАНК
 ID ТЕРМІНАЛА: 22300118
 ID ТОЧКИ:     22300023
 ------------------------------------
               ЧЕК 3615
            ОПЛАТА ТОВАРУ
 СУМА:                      117.00
              УСПІШНО
 КОД ВІДПОВІДІ: 00
 Visa Credit                 3832
 4731XXXXXXXX8465           xx/xx
  /
                    A000000031010
 КОД АВТОРИЗАЦІЇ:          822750
 НОМЕР ПОСИЛАННЯ:    912382214494
 ПОРЯД. НОМЕР:             003862
 НОМЕР ЦИКЛУ:              002152
 ДАТА: 03/05/2019   ЧАС: 20:59:55
 Ingenico Group.TE80187.20/12/18
 ------------------------------------
 ------------------------------------
  Поділись з нами своїми враженнями
  від візиту на mctellus.com
  Ваш код для опитування:
      02B8-E5YG-M11X
 ------------------------------------
 000011264 00049            3.05.2019 20:59
           МакДональдз № 14
           
           ВДЯЧНІ ЗА ВІЗИТ!
           www.mcdonalds.ua
          ФІКСАЛЬНИЙ ЧЕК DY
'''

bill_img_draw.text((30, 10), a, fill=1, font=unicode_font)

# %%
bill_img
# Out:
# <PIL.Image.Image image mode=RGB size=350x1000 at 0x7F4D8FFAB550>
